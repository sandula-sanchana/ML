# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error as rmean_squared_error



df=pd.read_csv("adv.csv")

X=df[['TV']]
Y=df['Sales']


X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)



model=LinearRegression()
model.fit(X_train,Y_train)

print(model.coef_)
print(model.intercept_)


Y_pred_test=model.predict(X_test)
Y_train_pred = model.predict(X_train)

train_rmse = rmean_squared_error(Y_train, Y_train_pred)
test_rmse = rmean_squared_error(Y_test, Y_pred)

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)

new_data= [[220]]

predicted_sales=model.predict(new_data)

print("Predicted sales for TV advertising expenditure of 220:", predicted_sales[0])
# Out:
# [0.05548294]
# 7.007108428241848
# Train RMSE: 2.235719650683013
# Test RMSE: 2.470035001123256
# Predicted sales for TV advertising expenditure of 220: 19.213356093163753
# /home/sandula-sanchana/.local/share/virtualenvs/ML-J88d3MkQ/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
